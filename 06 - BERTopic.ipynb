# %% [markdown]
# ## Topic modeling on ChiLit corpus with BERTopic and OPTUNA optimization

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ChiLit_Topic_Modeling
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ChiLit_Topic_Modeling

# %%
# !pip install git+https://github.com/tonazzog/OCTIS.git

# %%
# !pip install bertopic
# !pip install optuna
# !pip install gensim

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from sentence_transformers import SentenceTransformer
from octis.evaluation_metrics.diversity_metrics import TopicDiversity
from octis.evaluation_metrics.coherence_metrics import Coherence
import optuna
from umap import UMAP
from hdbscan import HDBSCAN
from gensim.corpora import Dictionary
import pandas as pd
from typing import Tuple, List
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import json
warnings.filterwarnings('ignore')

# %%
chunk_size = 200
optuna_folder = f"./optuna_{chunk_size}/"

# %%
df_chilit = pd.read_csv(f"./data/ChiLit_Chunks_{chunk_size}.csv")
df_chilit = df_chilit.fillna("")
sentences = df_chilit['tokens'].to_list()

# %%
df_chilit.head()
# Out:
#   book_id  chapter_num  paragraph_num  \
# 0   alice            1              1
# 1   alice            1              2
# 2   alice            2              1
# 3   alice            2              2
# 4   alice            3              1
#
#                                       paragraph_text  \
# 0  CHAPTER I. Down the Rabbit-Hole Alice was begi...
# 1  Alice was not a bit hurt, and she jumped up on...
# 2  ‘Curiouser and curiouser!’ cried Alice (she wa...
# 3       ‘How doth the little crocodile       Impr...
# 4  CHAPTER III. A Caucus-Race and a Long Tale The...
#
#                                               tokens
# 0  hole begin tired sit sister bank peep book sis...
# 1  bit hurt jump foot moment dark long passage wh...
# 2  curiouser curiouser cry surprise moment forget...
# 3  crocodile improve shine tail pour water golden...
# 4  race long tale queer party assemble bank bird ...

# %% [markdown]
# ### Remove noisy tokens

# %%
df_books = df_chilit.groupby('book_id', as_index=False).agg({
    'tokens': lambda x: ' '.join(x)
})

# %%
df_books.head()
# Out:
#   book_id                                             tokens
# 0   alice  hole begin tired sit sister bank peep book sis...
# 1   alone   close sultry day hot dog day open country dus...
# 2  amulet  chapter psammead child spend summer holiday wh...
# 3  beauty  chapter early home first place remember large ...
# 4   brass  receive commission day week week half pull wat...

# %%
docs = df_books['tokens'].to_list()

# Create TF-IDF matrix
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(docs)

# Get feature (term) names
terms = vectorizer.get_feature_names_out()

# %%
idf_values = vectorizer.idf_
idf_df = pd.DataFrame({
    'term': terms,
    'idf': idf_values
}).sort_values(by='idf', ascending=False)

# %%
idf_df[-61:]
# Out:
#         term       idf
# 6252   drive  1.057158
# 20605  thing  1.042560
# 1625   begin  1.042560
# 12201   lose  1.042560
# 22917   walk  1.042560
# ...      ...       ...
# 2789    call  1.013986
# 20913    top  1.000000
# 9577    head  1.000000
# 11815  leave  1.000000
# 20773   time  1.000000
#
# [61 rows x 2 columns]

# %%
# IDF close to 1 means the word appears in almost every document (stopword-like behavior)
filtered_terms = idf_df[idf_df['idf'] < 1.05]['term'].to_list()

# %%
len(filtered_terms)
# Out:
# 60

# %% [markdown]
# ### Remove other not interesting tokens

# %%
filter_tokens = ['thing','other','day','time','give','old','great','man','way','hand','boy','find','seem']

# %%
filter_sent = []
for sentence in sentences:
  words = ''
  for word in sentence.split():
    if word not in filter_tokens + filtered_terms:
      words += word + ' '
  filter_sent.append(words)

# %%
sentences = filter_sent

# %%
len(sentences)
# Out:
# 5843

# %%
with open("./data/BERTopic_Documents.txt", 'w') as file:
    file.write('\n'.join(sentences))

# %% [markdown]
# ### Pre-compute embedding

# %%
print("Loading data...")
documents = sentences

# Pre-compute embeddings to save time during optimization
print("Computing embeddings...")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = embedding_model.encode(documents, show_progress_bar=True)
# Out:
# Loading data...
# Computing embeddings...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]

# %% [markdown]
# ### OPTUNA multi-objective optimization

# %%
def create_bertopic_model(trial, documents):
    """Create BERTopic model with trial-suggested parameters"""

    # UMAP parameters
    umap_n_neighbors = trial.suggest_int('umap_n_neighbors', 5, 15)
    umap_n_components = trial.suggest_int('umap_n_components', 2, 10)
    umap_min_dist = trial.suggest_float('umap_min_dist', 0.0, 0.2)
    umap_metric = trial.suggest_categorical('umap_metric', ['euclidean', 'manhattan', 'cosine'])

    # HDBSCAN parameters
    hdbscan_min_cluster_size = trial.suggest_int('hdbscan_min_cluster_size', 5, 50)
    hdbscan_min_samples = trial.suggest_int('hdbscan_min_samples', 1, 10)
    hdbscan_metric = trial.suggest_categorical('hdbscan_metric', ['euclidean', 'manhattan'])
    hdbscan_cluster_selection_method = trial.suggest_categorical(
        'hdbscan_cluster_selection_method', ['eom', 'leaf']
    )

    # BERTopic parameters
    nr_topics = trial.suggest_int('nr_topics', 10, 50)

    # Create components
    embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

    umap_model = UMAP(
        n_neighbors=umap_n_neighbors,
        n_components=umap_n_components,
        min_dist=umap_min_dist,
        metric=umap_metric,
        random_state=42
    )

    hdbscan_model = HDBSCAN(
        min_cluster_size=hdbscan_min_cluster_size,
        min_samples=hdbscan_min_samples,
        metric=hdbscan_metric,
        cluster_selection_method=hdbscan_cluster_selection_method
    )


    # Create BERTopic model
    topic_model = BERTopic(
        nr_topics=nr_topics,
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        verbose=False
    )

    return topic_model

def evaluate_model(topic_model, documents, embeddings) -> Tuple[float, float]:
    """Evaluate the topic model using multiple metrics"""
    try:
        # Fit the model
        topics, _ = topic_model.fit_transform(documents, embeddings)

        # Get topic info
        topic_info = topic_model.get_topic_info()

        topics = []
        for key, value in topic_model.get_topics().items():
          topic = [v[0] for v in value]
          topics.append(topic)

        texts = [s.split() for s in sentences]

        output = {}
        output['topics'] = topics

        coherence_metrics = Coherence(texts=texts, #list of our documents
                            measure='c_npmi')
        coherence = coherence_metrics.score(output)

        diverisity_metric = TopicDiversity(topk=10)
        diversity = diverisity_metric.score(output)

        return coherence, diversity

    except Exception as e:
        print(f"Error in evaluation: {e}")
        return -1000, -1000

def objective(trial) -> Tuple[float, float]:
    """Objective function for Optuna optimization"""

    # Create model with trial parameters
    topic_model = create_bertopic_model(trial, documents)

    # Evaluate model
    cohrence, diversity = evaluate_model(topic_model, documents, embeddings)

    return cohrence, diversity

# %%
optuna.delete_study(
    storage=f"sqlite:///{optuna_folder}BERTopic_Study.db",
    study_name="BERTopic_Study"
)

# %%
# Main optimization code

# Create study
print("Starting optimization...")
study = optuna.create_study(
    directions=['maximize', 'maximize'],
    storage=f"sqlite:///{optuna_folder}BERTopic_Study.db",
    study_name="BERTopic_Study"
)

# Optimize
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-08-19 17:33:21,274] A new study created in RDB with name: BERTopic_Study
# Starting optimization...
# [I 2025-08-19 17:34:00,196] Trial 0 finished with values: [-0.008262954505367686, 0.5676328502415459] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 4, 'umap_min_dist': 0.0470072746289125, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 8, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 48}.
# [I 2025-08-19 17:34:43,057] Trial 1 finished with values: [0.07017730930647059, 0.609375] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 7, 'umap_min_dist': 0.07939330693118757, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 22, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 47}.
# [I 2025-08-19 17:35:14,930] Trial 2 finished with values: [0.08847918429428404, 0.6692307692307692] and parameters: {'umap_n_neighbors': 10, 'umap_n_components': 8, 'umap_min_dist': 0.07548277963135062, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 16, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 28}.
# [I 2025-08-19 17:35:45,741] Trial 3 finished with values: [0.08928982775058987, 0.668] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 4, 'umap_min_dist': 0.11806057428370278, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 17, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 39}.
# [I 2025-08-19 17:36:04,669] Trial 4 finished with values: [0.03613205111380886, 0.95] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 2, 'umap_min_dist': 0.0387983412400543, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 32, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 39}.
# [I 2025-08-19 17:36:33,156] Trial 5 finished with values: [0.08149101416286755, 0.65] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 3, 'umap_min_dist': 0.009232006872720744, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 39, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 50}.
# [I 2025-08-19 17:36:55,199] Trial 6 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 5, 'umap_min_dist': 0.11121698890229344, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 34, 'hdbscan_min_samples': 5, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 35}.
# [I 2025-08-19 17:37:24,302] Trial 7 finished with values: [0.09752860700617953, 0.7291666666666666] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 5, 'umap_min_dist': 0.1280022733313854, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 49, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 50}.
# [I 2025-08-19 17:37:55,160] Trial 8 finished with values: [0.08967517098238863, 0.7518518518518519] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 6, 'umap_min_dist': 0.14339078194616095, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 30, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 14}.
# [I 2025-08-19 17:38:20,723] Trial 9 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 9, 'umap_min_dist': 0.12988187028883644, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 14, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 43}.
# [I 2025-08-19 17:38:53,661] Trial 10 finished with values: [0.061862461733281617, 0.5625] and parameters: {'umap_n_neighbors': 10, 'umap_n_components': 3, 'umap_min_dist': 0.04145735305825942, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 15, 'hdbscan_min_samples': 3, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 28}.
# [I 2025-08-19 17:39:14,700] Trial 11 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 10, 'umap_n_components': 3, 'umap_min_dist': 0.12847872729435447, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 28, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 46}.
# [I 2025-08-19 17:39:43,216] Trial 12 finished with values: [0.07468594759983542, 0.575] and parameters: {'umap_n_neighbors': 5, 'umap_n_components': 6, 'umap_min_dist': 0.0356052226161506, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 25, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 49}.
# [I 2025-08-19 17:40:03,095] Trial 13 finished with values: [0.05839233364874164, 0.875] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 7, 'umap_min_dist': 0.10733999616393311, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 26, 'hdbscan_min_samples': 5, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 12}.
# [I 2025-08-19 17:40:36,299] Trial 14 finished with values: [0.03580747179868281, 0.5943548387096774] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 5, 'umap_min_dist': 0.1518771082111926, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 8, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 35}.
# [I 2025-08-19 17:40:56,641] Trial 15 finished with values: [0.06193677922814219, 0.9666666666666667] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 6, 'umap_min_dist': 0.12312376285124821, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 35, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 20}.
# [I 2025-08-19 17:41:34,521] Trial 16 finished with values: [0.058673286556127434, 0.6506024096385542] and parameters: {'umap_n_neighbors': 15, 'umap_n_components': 8, 'umap_min_dist': 0.048225794923594134, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 9, 'hdbscan_min_samples': 8, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 49}.
# [I 2025-08-19 17:42:09,724] Trial 17 finished with values: [0.08775381102801992, 0.6796610169491526] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 7, 'umap_min_dist': 0.07123550498462215, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 12, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 44}.
# [I 2025-08-19 17:42:38,410] Trial 18 finished with values: [0.092970087395529, 0.7346153846153847] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 10, 'umap_min_dist': 0.16431514180698778, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 33, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 40}.
# [I 2025-08-19 17:43:06,378] Trial 19 finished with values: [0.08046656897002631, 0.692] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 3, 'umap_min_dist': 0.13921032788001295, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 41, 'hdbscan_min_samples': 5, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 39}.
# [I 2025-08-19 17:43:39,586] Trial 20 finished with values: [0.06817235817867287, 0.5636363636363636] and parameters: {'umap_n_neighbors': 8, 'umap_n_components': 10, 'umap_min_dist': 0.020493552904312675, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 25, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 48}.
# [I 2025-08-19 17:44:08,330] Trial 21 finished with values: [0.11450212105816757, 0.8615384615384616] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 6, 'umap_min_dist': 0.07800012047188168, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 50, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 12}.
# [I 2025-08-19 17:44:28,134] Trial 22 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 2, 'umap_min_dist': 0.11026533232395688, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 22, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 30}.
# [I 2025-08-19 17:44:52,699] Trial 23 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 7, 'umap_min_dist': 0.13738737375966978, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 13, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 21}.
# [I 2025-08-19 17:45:20,250] Trial 24 finished with values: [0.09588651920813883, 0.653125] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 9, 'umap_min_dist': 0.11584138708289887, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 33, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 35}.
# [I 2025-08-19 17:45:44,658] Trial 25 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 8, 'umap_min_dist': 0.18114594615593613, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 25, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 20}.
# [I 2025-08-19 17:46:19,543] Trial 26 finished with values: [0.03316056496146749, 0.61953125] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 8, 'umap_min_dist': 0.1460313974249454, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 8, 'hdbscan_min_samples': 5, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 35}.
# [I 2025-08-19 17:46:55,325] Trial 27 finished with values: [0.052130953286857455, 0.5912621359223301] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 7, 'umap_min_dist': 0.15775393038405405, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 13, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 16}.
# [I 2025-08-19 17:47:21,583] Trial 28 finished with values: [0.0733295658180939, 0.5534883720930233] and parameters: {'umap_n_neighbors': 5, 'umap_n_components': 6, 'umap_min_dist': 0.009047484590503552, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 41, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 40}.
# [I 2025-08-19 17:47:51,949] Trial 29 finished with values: [0.09476382970243391, 0.7391304347826086] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 10, 'umap_min_dist': 0.17723649434289404, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 43, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 36}.
# [I 2025-08-19 17:48:24,445] Trial 30 finished with values: [0.06377538204613803, 0.5656716417910448] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 7, 'umap_min_dist': 0.02958745417037714, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 19, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 37}.
# [I 2025-08-19 17:48:44,073] Trial 31 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 3, 'umap_min_dist': 0.01564789116625902, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 13, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 20}.
# [I 2025-08-19 17:49:06,896] Trial 32 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 6, 'umap_min_dist': 0.07394442227483762, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 20, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 37}.
# [I 2025-08-19 17:49:33,706] Trial 33 finished with values: [0.09537904148196588, 0.68] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 9, 'umap_min_dist': 0.11374119004465887, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 35, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 12}.
# [I 2025-08-19 17:50:01,933] Trial 34 finished with values: [0.08576611500072724, 0.7] and parameters: {'umap_n_neighbors': 8, 'umap_n_components': 9, 'umap_min_dist': 0.11054770015486644, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 46, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 26}.
# [I 2025-08-19 17:50:32,829] Trial 35 finished with values: [0.1001131431229847, 0.7269230769230769] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 7, 'umap_min_dist': 0.15617047466094638, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 30, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 29}.
# [I 2025-08-19 17:51:04,048] Trial 36 finished with values: [0.0840472688670991, 0.6292307692307693] and parameters: {'umap_n_neighbors': 10, 'umap_n_components': 7, 'umap_min_dist': 0.10610517771844981, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 17, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 30}.
# [I 2025-08-19 17:51:31,404] Trial 37 finished with values: [0.09295613990739703, 0.676923076923077] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 4, 'umap_min_dist': 0.1253921440528087, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 38, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 31}.
# [I 2025-08-19 17:52:08,158] Trial 38 finished with values: [0.027120273495115577, 0.6053435114503817] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 8, 'umap_min_dist': 0.041926928616855055, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 8, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 36}.
# [I 2025-08-19 17:52:39,660] Trial 39 finished with values: [0.060945662170517695, 0.648314606741573] and parameters: {'umap_n_neighbors': 8, 'umap_n_components': 5, 'umap_min_dist': 0.16695250497462716, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 9, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 46}.
# [I 2025-08-19 17:53:02,664] Trial 40 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 9, 'umap_n_components': 8, 'umap_min_dist': 0.08659556223241338, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 38, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 45}.
# [I 2025-08-19 17:53:30,231] Trial 41 finished with values: [0.04800528677116994, 0.4822916666666667] and parameters: {'umap_n_neighbors': 5, 'umap_n_components': 2, 'umap_min_dist': 0.10343095062420622, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 23, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 44}.
# [I 2025-08-19 17:54:07,960] Trial 42 finished with values: [-0.035536691549140305, 0.5658730158730159] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 5, 'umap_min_dist': 0.10966601721531558, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 8, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 50}.
# [I 2025-08-19 17:54:33,718] Trial 43 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 9, 'umap_min_dist': 0.05873197854306536, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 28, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 43}.
# [I 2025-08-19 17:55:09,912] Trial 44 finished with values: [0.006470639341964469, 0.627972027972028] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 10, 'umap_min_dist': 0.028074245861476, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 6, 'hdbscan_min_samples': 8, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 30}.
# [I 2025-08-19 17:55:39,771] Trial 45 finished with values: [0.08242910466675209, 0.6675675675675675] and parameters: {'umap_n_neighbors': 9, 'umap_n_components': 6, 'umap_min_dist': 0.1559334320991871, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 29, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 16}.
# [I 2025-08-19 17:56:14,864] Trial 46 finished with values: [0.023926009013850228, 0.5846774193548387] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 4, 'umap_min_dist': 0.09188028541615878, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 12, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 22}.
# [I 2025-08-19 17:56:47,459] Trial 47 finished with values: [0.027828749059989125, 0.6416] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 4, 'umap_min_dist': 0.1621424206167685, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 7, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 49}.
# [I 2025-08-19 17:57:18,816] Trial 48 finished with values: [0.08184022322399456, 0.6571428571428571] and parameters: {'umap_n_neighbors': 15, 'umap_n_components': 6, 'umap_min_dist': 0.011769231457858843, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 28, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 49}.
# [I 2025-08-19 17:57:50,508] Trial 49 finished with values: [0.0849125624486857, 0.5984615384615385] and parameters: {'umap_n_neighbors': 9, 'umap_n_components': 8, 'umap_min_dist': 0.05859661339413085, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 24, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 17}.
# [I 2025-08-19 17:58:10,789] Trial 50 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 15, 'umap_n_components': 2, 'umap_min_dist': 0.17723649434289404, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 32, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 36}.
# [I 2025-08-19 17:58:39,526] Trial 51 finished with values: [0.08878285934694874, 0.7137931034482758] and parameters: {'umap_n_neighbors': 9, 'umap_n_components': 8, 'umap_min_dist': 0.08659556223241338, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 38, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 28}.
# [I 2025-08-19 17:59:09,997] Trial 52 finished with values: [0.08928982775058987, 0.668] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 4, 'umap_min_dist': 0.11806057428370278, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 17, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 39}.
# [I 2025-08-19 17:59:43,925] Trial 53 finished with values: [0.03652876936391614, 0.5433070866141733] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 3, 'umap_min_dist': 0.009232006872720744, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 14, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 50}.
# [I 2025-08-19 18:00:07,043] Trial 54 finished with values: [0.039536813406135796, 0.8] and parameters: {'umap_n_neighbors': 8, 'umap_n_components': 9, 'umap_min_dist': 0.16431514180698778, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 46, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 40}.
# [I 2025-08-19 18:00:37,271] Trial 55 finished with values: [0.09010200247426865, 0.6833333333333333] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 7, 'umap_min_dist': 0.14339078194616095, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 30, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 14}.
# [I 2025-08-19 18:01:18,319] Trial 56 finished with values: [-0.0025422827724659444, 0.5814814814814815] and parameters: {'umap_n_neighbors': 15, 'umap_n_components': 8, 'umap_min_dist': 0.05859661339413085, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 9, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 17}.
# [I 2025-08-19 18:01:51,868] Trial 57 finished with values: [0.054950084995063944, 0.5534246575342465] and parameters: {'umap_n_neighbors': 5, 'umap_n_components': 9, 'umap_min_dist': 0.11054770015486644, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 19, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 26}.
# [I 2025-08-19 18:02:22,255] Trial 58 finished with values: [0.07149376632343718, 0.6275362318840579] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 4, 'umap_min_dist': 0.11806057428370278, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 17, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 39}.
# [I 2025-08-19 18:02:41,891] Trial 59 finished with values: [0.07671987788237498, 0.9666666666666667] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 2, 'umap_min_dist': 0.0387983412400543, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 16, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 44}.
# [I 2025-08-19 18:03:04,293] Trial 60 finished with values: [0.09086575669999311, 0.9] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 2, 'umap_min_dist': 0.07800012047188168, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 50, 'hdbscan_min_samples': 5, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 12}.
# [I 2025-08-19 18:03:37,631] Trial 61 finished with values: [0.07740154721920829, 0.6820512820512821] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 6, 'umap_min_dist': 0.031541287294104374, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 30, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 14}.
# [I 2025-08-19 18:04:09,409] Trial 62 finished with values: [0.08370994923705244, 0.64375] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 6, 'umap_min_dist': 0.021743790054621927, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 24, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 50}.
# [I 2025-08-19 18:04:42,721] Trial 63 finished with values: [0.03666755624340939, 0.6505050505050505] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 8, 'umap_min_dist': 0.1621424206167685, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 8, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 49}.
# [I 2025-08-19 18:05:16,689] Trial 64 finished with values: [0.08289225699274472, 0.6175] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 9, 'umap_min_dist': 0.1253921440528087, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 15, 'hdbscan_min_samples': 3, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 31}.
# [I 2025-08-19 18:05:45,429] Trial 65 finished with values: [0.08745853285807906, 0.7241379310344828] and parameters: {'umap_n_neighbors': 9, 'umap_n_components': 8, 'umap_min_dist': 0.08659556223241338, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 38, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 47}.
# [I 2025-08-19 18:06:17,849] Trial 66 finished with values: [0.10825084675673761, 0.7428571428571429] and parameters: {'umap_n_neighbors': 15, 'umap_n_components': 9, 'umap_min_dist': 0.11054770015486644, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 46, 'hdbscan_min_samples': 8, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 49}.
# [I 2025-08-19 18:06:40,719] Trial 67 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 6, 'umap_min_dist': 0.07394442227483762, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 20, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 37}.
# [I 2025-08-19 18:07:09,248] Trial 68 finished with values: [0.11144559350383423, 0.84] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 10, 'umap_min_dist': 0.17723649434289404, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 39, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 36}.
# [I 2025-08-19 18:07:43,105] Trial 69 finished with values: [0.06477664086810139, 0.663013698630137] and parameters: {'umap_n_neighbors': 15, 'umap_n_components': 8, 'umap_min_dist': 0.048225794923594134, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 9, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 28}.
# [I 2025-08-19 18:08:19,175] Trial 70 finished with values: [0.03413672001019508, 0.5754237288135593] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 7, 'umap_min_dist': 0.02958745417037714, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 11, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 37}.
# [I 2025-08-19 18:08:43,899] Trial 71 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 9, 'umap_min_dist': 0.05873197854306536, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 28, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 39}.
# [I 2025-08-19 18:09:02,797] Trial 72 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 10, 'umap_n_components': 3, 'umap_min_dist': 0.05873197854306536, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 15, 'hdbscan_min_samples': 3, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 28}.
# [I 2025-08-19 18:09:25,054] Trial 73 finished with values: [0.06193677922814219, 0.9666666666666667] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 10, 'umap_min_dist': 0.16431514180698778, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 25, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 20}.
# [I 2025-08-19 18:09:50,381] Trial 74 finished with values: [0.07225187219424828, 0.9333333333333333] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 9, 'umap_min_dist': 0.1557176433073476, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 28, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 43}.
# [I 2025-08-19 18:10:24,981] Trial 75 finished with values: [0.012543175302904953, 0.6202898550724638] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 10, 'umap_min_dist': 0.028074245861476, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 6, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 30}.
# [I 2025-08-19 18:10:52,351] Trial 76 finished with values: [0.09269078723190802, 0.6266666666666667] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 6, 'umap_min_dist': 0.12312376285124821, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 33, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 35}.
# [I 2025-08-19 18:11:17,008] Trial 77 finished with values: [0.0789286801183631, 0.6517241379310345] and parameters: {'umap_n_neighbors': 5, 'umap_n_components': 6, 'umap_min_dist': 0.16695250497462716, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 41, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 40}.
# [I 2025-08-19 18:11:39,760] Trial 78 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 7, 'umap_min_dist': 0.10610517771844981, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 30, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 46}.
# [I 2025-08-19 18:12:15,740] Trial 79 finished with values: [0.006470639341964469, 0.627972027972028] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 10, 'umap_min_dist': 0.028074245861476, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 6, 'hdbscan_min_samples': 8, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 30}.
# [I 2025-08-19 18:12:42,035] Trial 80 finished with values: [0.08692285700304012, 0.6733333333333333] and parameters: {'umap_n_neighbors': 6, 'umap_n_components': 7, 'umap_min_dist': 0.11374119004465887, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 35, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 29}.
# [I 2025-08-19 18:13:03,068] Trial 81 finished with values: [0.07225187219424828, 0.9333333333333333] and parameters: {'umap_n_neighbors': 7, 'umap_n_components': 9, 'umap_min_dist': 0.13738737375966978, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 35, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 21}.
# [I 2025-08-19 18:13:32,615] Trial 82 finished with values: [0.06362551654573623, 0.6071428571428571] and parameters: {'umap_n_neighbors': 5, 'umap_n_components': 6, 'umap_min_dist': 0.07123550498462215, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 12, 'hdbscan_min_samples': 10, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 44}.
# [I 2025-08-19 18:13:53,844] Trial 83 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 8, 'umap_n_components': 10, 'umap_min_dist': 0.020493552904312675, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 25, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 43}.
# [I 2025-08-19 18:14:24,051] Trial 84 finished with values: [0.08893152611108648, 0.7038461538461539] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 6, 'umap_min_dist': 0.13921032788001295, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 41, 'hdbscan_min_samples': 2, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 39}.
# [I 2025-08-19 18:14:44,101] Trial 85 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 3, 'umap_min_dist': 0.01564789116625902, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 34, 'hdbscan_min_samples': 3, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 12}.
# [I 2025-08-19 18:15:11,436] Trial 86 finished with values: [0.08488822318075132, 0.578] and parameters: {'umap_n_neighbors': 5, 'umap_n_components': 8, 'umap_min_dist': 0.08659556223241338, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 24, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 17}.
# [I 2025-08-19 18:15:36,630] Trial 87 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 14, 'umap_n_components': 10, 'umap_min_dist': 0.11121698890229344, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 34, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 35}.
# [I 2025-08-19 18:15:58,779] Trial 88 finished with values: [0.03497743150807333, 0.7333333333333333] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 4, 'umap_min_dist': 0.1253921440528087, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 50, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 31}.
# [I 2025-08-19 18:16:27,955] Trial 89 finished with values: [0.10073063658922464, 0.7666666666666667] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 9, 'umap_min_dist': 0.15775393038405405, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 47, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 43}.
# [I 2025-08-19 18:16:56,002] Trial 90 finished with values: [0.09271653811448931, 0.7227272727272728] and parameters: {'umap_n_neighbors': 8, 'umap_n_components': 9, 'umap_min_dist': 0.12847872729435447, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 50, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 46}.
# [I 2025-08-19 18:17:19,570] Trial 91 finished with values: [0.03613205111380886, 0.95] and parameters: {'umap_n_neighbors': 11, 'umap_n_components': 8, 'umap_min_dist': 0.0387983412400543, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 32, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 12}.
# [I 2025-08-19 18:17:49,577] Trial 92 finished with values: [0.09473447857326962, 0.725] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 7, 'umap_min_dist': 0.14339078194616095, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 30, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 14}.
# [I 2025-08-19 18:18:20,768] Trial 93 finished with values: [0.06487194276392348, 0.6319444444444444] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 3, 'umap_min_dist': 0.04145735305825942, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 15, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 28}.
# [I 2025-08-19 18:18:43,774] Trial 94 finished with values: [0.04035370427711367, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 7, 'umap_min_dist': 0.12312376285124821, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 9, 'hdbscan_min_samples': 8, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 29}.
# [I 2025-08-19 18:19:04,369] Trial 95 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 12, 'umap_n_components': 2, 'umap_min_dist': 0.10702892482487834, 'umap_metric': 'euclidean', 'hdbscan_min_cluster_size': 31, 'hdbscan_min_samples': 4, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 30}.
# [I 2025-08-19 18:19:23,045] Trial 96 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 10, 'umap_n_components': 3, 'umap_min_dist': 0.02958745417037714, 'umap_metric': 'cosine', 'hdbscan_min_cluster_size': 19, 'hdbscan_min_samples': 7, 'hdbscan_metric': 'euclidean', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 37}.
# [I 2025-08-19 18:19:44,573] Trial 97 finished with values: [0.03613205111380885, 0.95] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 3, 'umap_min_dist': 0.05873197854306536, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 25, 'hdbscan_min_samples': 6, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 43}.
# [I 2025-08-19 18:20:19,915] Trial 98 finished with values: [0.05165558002656352, 0.5867469879518072] and parameters: {'umap_n_neighbors': 13, 'umap_n_components': 9, 'umap_min_dist': 0.12988187028883644, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 14, 'hdbscan_min_samples': 1, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'eom', 'nr_topics': 43}.
# [I 2025-08-19 18:20:48,581] Trial 99 finished with values: [0.08745853285807906, 0.7241379310344828] and parameters: {'umap_n_neighbors': 9, 'umap_n_components': 8, 'umap_min_dist': 0.08659556223241338, 'umap_metric': 'manhattan', 'hdbscan_min_cluster_size': 38, 'hdbscan_min_samples': 9, 'hdbscan_metric': 'manhattan', 'hdbscan_cluster_selection_method': 'leaf', 'nr_topics': 44}.

# %%
def train_final_BERTopic_model(params, embeddings):
    """Create BERTopic model with trial-suggested parameters"""

    # UMAP parameters
    umap_n_neighbors = params['umap_n_neighbors']
    umap_n_components = params['umap_n_components']
    umap_min_dist = params['umap_min_dist']
    umap_metric = params['umap_metric']

    # HDBSCAN parameters
    hdbscan_min_cluster_size = params['hdbscan_min_cluster_size']
    hdbscan_min_samples = params['hdbscan_min_samples']
    hdbscan_metric = params['hdbscan_metric']
    hdbscan_cluster_selection_method = params['hdbscan_cluster_selection_method']

    # BERTopic parameters
    nr_topics = params['nr_topics']

    # Create components
    embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

    umap_model = UMAP(
        n_neighbors=umap_n_neighbors,
        n_components=umap_n_components,
        min_dist=umap_min_dist,
        metric=umap_metric,
        random_state=42
    )

    hdbscan_model = HDBSCAN(
        min_cluster_size=hdbscan_min_cluster_size,
        min_samples=hdbscan_min_samples,
        metric=hdbscan_metric,
        cluster_selection_method=hdbscan_cluster_selection_method,
        prediction_data=True
    )

    # Create BERTopic model
    topic_model = BERTopic(
        nr_topics=nr_topics,
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        verbose=False,
        calculate_probabilities=True
    )

    topics, probs = topic_model.fit_transform(documents, embeddings)

    # Get topic info
    topic_info = topic_model.get_topic_info()

    topics = []
    for key, value in topic_model.get_topics().items():
      topic = [v[0] for v in value]
      topics.append(topic)

    texts = [s.split() for s in sentences]

    output = {}
    output['topics'] = topics

    coherence_metrics = Coherence(texts=texts, #list of our documents
                        measure='c_npmi')
    coherence = coherence_metrics.score(output)

    diverisity_metric = TopicDiversity(topk=10)
    diversity = diverisity_metric.score(output)

    return topic_model, coherence, diversity

# %%
BERTopic_study = optuna.load_study(
    storage=f"sqlite:///{optuna_folder}BERTopic_Study.db",
    study_name="BERTopic_Study"
)

# %%
if BERTopic_study.best_trials:
    # Get balanced solution
    pareto_trials = BERTopic_study.best_trials

    # Pick the first Pareto optimal solution
    selected_params = pareto_trials[0].params
    final_model, final_coherence, final_diversity = train_final_BERTopic_model(selected_params, embeddings)

    print(f"\nFinal model trained successfully!")
# Out:
# Final model trained successfully!

# %%
selected_params
# Out:
# {'umap_n_neighbors': 14,
#  'umap_n_components': 6,
#  'umap_min_dist': 0.07800012047188168,
#  'umap_metric': 'manhattan',
#  'hdbscan_min_cluster_size': 50,
#  'hdbscan_min_samples': 9,
#  'hdbscan_metric': 'euclidean',
#  'hdbscan_cluster_selection_method': 'eom',
#  'nr_topics': 12}

# %%
print(f"Final model metrics:")
print(f"  Coherence: {final_coherence:.4f}")
print(f"  Diversity: {final_diversity:.4f}")
# Out:
# Final model metrics:
#   Coherence: 0.0901
#   Diversity: 0.8667

# %%
doc_topics = final_model.get_document_info(documents)

# %%
doc_topics.to_csv("./bertopic/doc_topics.csv", encoding="utf-8")

# %%
# Save model
embedding_model = "sentence-transformers/all-MiniLM-L6-v2"
final_model.save("./bertopic/", serialization="safetensors", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
# Reload saved model
embedding_model = "sentence-transformers/all-MiniLM-L6-v2"
final_model = BERTopic.load("./bertopic", embedding_model=embedding_model)

# %%
topics = final_model.get_topics()

# %%
topic_words = []
for key, topic in topics.items():
  if key != -1:
    topic_words.append(' '.join([word_info[0]  for word_info in topic]))

# %%
topic_words
# Out:
# ['father own dear much room poor hope love wish letter',
#  'weasel fly mulgar long tail big bird night stand squirrel',
#  'ship sea boat captain island sail deck shore wind vessel',
#  'school fellow study paper room fifth mind mean own form',
#  'mother child father ask want baby girl room lady like',
#  'attack force enemy fire troops fort gun army french advance',
#  'king queen prince royal person family lady palace knight princess',
#  'night light dream cry fall face voice sleep lie heart',
#  'horse master driver cab engine rein train drive carriage stable',
#  'reply cottage indian forest animal dog lodge rifle intendant venison',
#  'rock chalk volcano earthquake lava ice sea stone sand mountain']

# %%
# Load topic labels
with open("./bertopic/BERTopic_Topic_Labels.json", 'r') as file:
  BERTopic_labels = json.load(file)

# %%
topic_labels = [value['primary_label'].lower() for key, value in BERTopic_labels.items()]
topic_labels.insert(0, '-')
final_model.set_topic_labels(topic_labels)

# %%
# Visualize the topics
fig = final_model.visualize_barchart(top_n_topics=60, custom_labels=True)
fig.show()

# %% [markdown]
# ![image](data:image/png;base64,...)

# %%
fig = final_model.visualize_heatmap(custom_labels=True)
fig.show()

# %% [markdown]
# ![image](data:image/png;base64,...)

# %%
fig = final_model.visualize_topics(top_n_topics = 60, custom_labels=True)
fig.show()

# %% [markdown]
# ![image](data:image/png;base64,...)

# %%
final_model.visualize_documents(documents, embeddings=embeddings, custom_labels=True)

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# ### Topic relevance per book

# %%
doc_topics = pd.read_csv("./bertopic/doc_topics.csv", encoding="utf-8")
doc_topics = doc_topics.assign(row_number=range(len(doc_topics)))
doc_topics['book_id'] = df_chilit['book_id'].to_list()
doc_topics['paragraph_text'] = df_chilit['paragraph_text'].to_list()
doc_topics = doc_topics[['row_number','book_id','paragraph_text', 'Document', 'Topic', 'Probability']]

# %%
# 1. Aggregate total probability per (doc_id, topic)
topic_confidence = (
    doc_topics[doc_topics['Topic'] != -1]
    .groupby(["book_id", "Topic"])["Probability"]
    .mean()
    .reset_index()
)

# 2. Pivot into matrix form (rows = doc_id, cols = topic)
pivot_df = topic_confidence.pivot(
    index="book_id", columns="Topic", values="Probability"
).fillna(0)

# 3. Plot heatmap
plt.figure(figsize=(10, 16))
sns.heatmap(
    pivot_df,
    annot=False, fmt=".2f", cmap="YlGnBu",
    #cbar_kws={"label": "Topic relevance heatmap"},
    xticklabels = topic_labels[1:]
)
plt.title("Topic Relevance Heatmap" + "\n")
plt.xlabel("Topic ID")
plt.ylabel("Original Document ID")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

plt.show()

# %%
# Utility function to embed saved images
import base64

def embed_image_md(path):
    return f"![image](data:image/{path.split('.')[-1]};base64,{base64.b64encode(open(path,'rb').read()).decode()})"

print(embed_image_md("./bertopic/Documents and Topics.png"))
