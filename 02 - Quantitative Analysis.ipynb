# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ChiLit_Topic_Modeling
# Out:
# /content/drive/MyDrive/ChiLit_Topic_Modeling

# %%
import nltk
from nltk.corpus.reader import PlaintextCorpusReader
from corpusanalyzer import CorpusAnalyzer
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\giovannt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
data_dir = './data/'
chilit = PlaintextCorpusReader(root = data_dir + "ChiLit", fileids = r'.+\.txt')

# %%
# Initialize analyzer
analyzer = CorpusAnalyzer(chilit)

# Perform analysis
individual_stats, corpus_summary, df = analyzer.analyze_corpus()

# %%
 # Print summary
analyzer.print_summary(individual_stats, corpus_summary)

# The DataFrame 'df' contains all the statistics and can be used for further analysis
print(f"\nDataFrame shape: {df.shape}")
print("\nDataFrame columns:", list(df.columns))
# Out:
# ...
# CORPUS ANALYSIS SUMMARY
# ...
#
# Corpus Overview:
#   Total documents: 71
#   Total words: 5,428,825
#   Total sentences: 232,137
#
# Document Statistics:
#   Average words per document: 76462.32 (±58249.25)
#   Range: 1122 - 368885 words
#   Average sentences per document: 3269.54
#
# Linguistic Metrics:
#   Average lexical density: 0.39
#   Average type-token ratio: 0.095
#   Average word length: 4.08 characters
#
# ...
# INDIVIDUAL DOCUMENT DETAILS
# ...
#
# Document: alice.txt
#   Words: 34,110 | Sentences: 1365
#   Avg words/sentence: 24.99
#   Lexical density: 0.359
#   Type-token ratio: 0.075
#   Top words: the(1643), and(872), to(729), a(632), it(595)
#   Top content words: said(462), alice(398), little(128), one(104), know(87)
#
# Document: alone.txt
#   Words: 33,382 | Sentences: 1385
#   Avg words/sentence: 24.1
#   Lexical density: 0.389
#   Type-token ratio: 0.091
#   Top words: and(1156), the(1095), to(748), he(697), a(650)
# ...

# %%
# Additional analysis
print(f"\nCorrelation between document length and lexical density:")
print(f"  Correlation coefficient: {df['total_words'].corr(df['lexical_density']):.3f}")
# Out:
# Correlation between document length and lexical density:
#   Correlation coefficient: -0.242

# %%
# Analysis of Document Lenghts
doc_lengths, stats = analyzer.analyze_document_lengths(individual_stats)
analyzer.plot_length_distribution(doc_lengths)

# %%
analyzer.plot_document_length(individual_stats)
